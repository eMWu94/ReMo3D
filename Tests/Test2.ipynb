# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
sys.path.append(module_path)

import src as rm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 7
#       4 module_path = os.path.abspath(os.path.join('..'))
#       5 sys.path.append(module_path)
# ----> 7 import src as rm
#
# File /mnt/c/users/MW/GitHub/ReMo3D/src/__init__.py:1
# ----> 1 from .remo3d import remo3d
#       2 # from .workers import worker
#       3 # from .utils import gmsh_functions, netgen_functions, ngsolve_functions
#       5 __all__ = ["remo3d"]
#
# File /mnt/c/users/MW/GitHub/ReMo3D/src/remo3d/remo3d.py:20
#      17 import os
#      19 # import gmsh
# ---> 20 from ..utils.gmsh_functions import AddPointsToBorehole
#      22 # import netgen.meshing as msh
#      23 # from netgen.csg import *
#      24 # from netgen.geom2d import SplineGeometry
#    (...)
#      29
#      30 ##  Main functions
#      32 def SetToolsParameters(tools):
#
# ...
